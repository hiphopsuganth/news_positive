# %% [markdown]
# <a href="https://colab.research.google.com/github/hiphopsuganth/news_positive/blob/main/news_positive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install feedparser
import feedparser
# pip install transformers
import requests

# %%
API_URL = "https://api-inference.huggingface.co/models/avichr/heBERT_sentiment_analysis"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

# %%
# URL of the RSS or Atom feed
feed_url = "https://www.thehindu.com/news/national/feeder/default.rss"

# Parse the feed
feed = feedparser.parse(feed_url)

# %%
entries = [entry['title'] + " " + entry.get('summary', '') for entry in feed.entries]

# %%
for entry in entries:
    output = query({"inputs": entry})

    # Access the first list in the output and iterate over its items
    for sentiment in output[0]:
        if sentiment['label'] == 'positive':
            print(f"Text: {entry}")
            print(f"Sentiment: {sentiment}")
            print("-" * 80)
            break  # Stop further checks if positive sentiment is found
# Out:
# Text: SC grants bail to K. Kavitha in excise policy cases BRS leader is all set to walk out of the prison as the Supreme Court has granted regular bail in both ED as well as the CBI’s cases on Delhi excise policy.
# Sentiment: {'label': 'positive', 'score': 0.00022604565310757607}
# --------------------------------------------------------------------------------
# Text: No benefit from Gruha Lakshmi yet, Mythri pension also not regular, say transwomen in Karnataka The officials from the Department of Women and Child Development said that while the facility for transgenders to avail the benefits of Gruha Lakshmi is open, many of them have not been able to avail it due to non-availability of TG cards
# Sentiment: {'label': 'positive', 'score': 0.00040798247209750116}
# --------------------------------------------------------------------------------
# Text: Supreme Court asks Kerala to clarify the number of witnesses left to be examined in the 2017 actor sexual assault case In August last year, the top court gave time till March 31, 2024 to finish the trial
# Sentiment: {'label': 'positive', 'score': 0.00016407818475272506}
# --------------------------------------------------------------------------------
# Text: Bangladeshi student sent back after 'love' emoji on anti-India post Cachar Superintendent of Police Numal Mahatta claimed that it was "not deportation" but was just sent back in consultation with Bangladesh authorities
# Sentiment: {'label': 'positive', 'score': 0.0001507458946434781}
# --------------------------------------------------------------------------------
# Text: Apology over ‘damaging’ statements: SC says excerpt filed by IMA president illegible, font miniscule The Bench directed senior advocate P S Patwalia, appearing for Dr. Asokan, to file physical copies of 20 editions of The Hindu newspaper in which his apology has been published within one week.
# Sentiment: {'label': 'positive', 'score': 0.002804802032187581}
# --------------------------------------------------------------------------------
# Text: A.P. High Court directs Eluru Collector to submit report on sexual assault of minor girl Doctors who examined the 15-year-girl reportedly confirmed that she was seven months pregnant.
# Sentiment: {'label': 'positive', 'score': 0.0001511353038949892}
# --------------------------------------------------------------------------------
# Text: Non-compliance with SNJPC proposals: Chief secretaries of 18 States, Union Territories appear in SC The top court took note of compliance affidavits of States and Union Territories and ordered the closure of proceedings against them.
# Sentiment: {'label': 'positive', 'score': 0.0036576727870851755}
# --------------------------------------------------------------------------------
# Text: Delhi excise policy scam: Supreme Court adjourns hearing on Vijay Nair's bail plea The top court had issued notice to the Enforcement Directorate (ED) on August 12 on the plea of Nair while noting that he has been in custody for two years.
# Sentiment: {'label': 'positive', 'score': 0.00017544528236612678}
# --------------------------------------------------------------------------------
# Text: Shivaji statue collapse: Case filed against contractor, structural consultant The PWD had flagged the rusting nuts and bolts as a threat to the Shivaji Maharaj statue’s stability, but these concerns were ignored, they told the police.
# Sentiment: {'label': 'positive', 'score': 8.430358866462484e-05}
# --------------------------------------------------------------------------------
# Text: Food poisoning incident in Mathura, around 50 hospitalised A resident who had come with a patient said after consuming the fritters people started complaining about dizziness, vomiting and shivering
# Sentiment: {'label': 'positive', 'score': 0.022730831056833267}
# --------------------------------------------------------------------------------
# Text: Eight fishermen from Rameswaram arrested by Sri Lankan Navy; one boat impounded They were reportedly fishing between Dhanushkodi and Talaimannar waters when the Sri Lankan Navy personnel captured them
# Sentiment: {'label': 'positive', 'score': 0.0006576411542482674}
# --------------------------------------------------------------------------------
# Text: National Conference issues first list of 18 candidates for Jammu and Kashmir Assembly polls National Conference (NC) in a post on X said the list was approved by party president Farooq Abdullah.
# Sentiment: {'label': 'positive', 'score': 0.00105466996319592}
# --------------------------------------------------------------------------------
# Text: Village Defence Guards open fire on observing suspicious movement in Jammu & Kashmir’s Rajouri Security forces cordoned off the village and carried out searches following the incident but there was no trace of the suspected persons
# Sentiment: {'label': 'positive', 'score': 0.0010064474772661924}
# --------------------------------------------------------------------------------
# Text: Bengali actor Ritabhari Chakraborty says sexual abuse exists in local entertainment industry Senior Bengali actor Sreelekha Mitra had recently levelled allegations of making improper advances against a renowned Malayalam director
# Sentiment: {'label': 'positive', 'score': 0.006571320816874504}
# --------------------------------------------------------------------------------
# Text: PM Modi to visit Singapore soon; semiconductors added to ministerial roundtable agenda This was the second time that ministers from Singapore and India met at the India-Singapore Ministerial Roundtable (ISMR) after its inaugural edition was launched in September 2022
# Sentiment: {'label': 'positive', 'score': 0.0014491233741864562}
# --------------------------------------------------------------------------------
# Text: One-week programme on AI-Based Biomedical Image Processing inaugurated at NITW
# Sentiment: {'label': 'positive', 'score': 0.0009822390275076032}
# --------------------------------------------------------------------------------
# Text: Telegram issue: IT Ministry asks MHA to check on status, violations in Indian context Telegram's founder and CEO was detained at Paris airport on an arrest warrant alleging his platform was used for offences like money laundering and drug trafficking.
# Sentiment: {'label': 'positive', 'score': 0.0012713944306597114}
# --------------------------------------------------------------------------------
# Text: Rain forecast for few districts of Telangana on August 27 Light to moderate rain or thundershowers accompanied with gusty winds are very likely to occur in Hyderabad
# Sentiment: {'label': 'positive', 'score': 0.007830833084881306}
# --------------------------------------------------------------------------------
# Text: Demolitions lead to tension in Raidurgam
# Sentiment: {'label': 'positive', 'score': 0.001916395965963602}
# --------------------------------------------------------------------------------
# Text: Navy team pulls out wreckage of missing aircraft from Chandil dam in Jharkhand The aircraft went missing after it took off from Sonari Aerodrome in Jamshedpur on August 20
# Sentiment: {'label': 'positive', 'score': 0.0016296303365379572}
# --------------------------------------------------------------------------------
# Text: Shivaji statue collapse: ‘100 ft statue must now be built’, says Maharashtra Minister Deepak Kesarkar Police filed an FIR against contractor Jaydeep Apte and structural consultant Chetan Patil following the collapse of the 35-foot Chhatrapati Shivaji Maharaj statue in Sindhudurg.
# Sentiment: {'label': 'positive', 'score': 0.005178086459636688}
# --------------------------------------------------------------------------------
# Text: How Ola’s shenanigans reached the gates of MapmyIndia In the run-up to IPO, Ola has been playing a few tricks that have now taken the ride-hailing firm and MapmyIndia into uncharted territory
# Sentiment: {'label': 'positive', 'score': 0.002748452126979828}
# --------------------------------------------------------------------------------
# Text: Water cannons, Barricades: Kolkata police puts in high-security ring at secretariat ahead of Nabanna Abhijan student protest The police deployed vajra vehicles, water cannons, and Riot Control Force in the area while containers were placed to block the roads
# Sentiment: {'label': 'positive', 'score': 0.0005133200320415199}
# --------------------------------------------------------------------------------
# Text: Gujarat rains LIVE updates: Eight killed in rain-related incidents; over 23,000 people shifted to safer places Ahmedabad Airport issues advisory on Tuesday (August 27, 2024) suggesting passengers to check flight schedules with airlines and allow extra time for check-in due to heavy rains.
# Sentiment: {'label': 'positive', 'score': 0.0017154656816273928}
# --------------------------------------------------------------------------------
# Text: Reporting cybercrime within golden hour on 112 is a challenge for citizens Citizens have reported that even when they dial 1930, the dedicated cybercrime helpline, it takes two to three tries to get an operator to talk to
# Sentiment: {'label': 'positive', 'score': 0.00020990069606341422}
# --------------------------------------------------------------------------------
# Text: Six militants arrested in Manipur Police recover weapons from the arrested cadres the proscribed outfit Kanglei Yawol Kanba Lup in Imphal West district.
# Sentiment: {'label': 'positive', 'score': 0.0002720955526456237}
# --------------------------------------------------------------------------------
# Text: Heavy rains in Gujarat; IMD issues ‘red alert’ in several districts The districts under IMD’s red alert are entire Saurashtra region, Kutch, Kheda, Anand, Panchmahal, Dahod, Tapi, Navsari and Valsad
# Sentiment: {'label': 'positive', 'score': 0.0024542012251913548}
# --------------------------------------------------------------------------------
# Text: Nabanna march LIVE: Police use water cannons to disperse protesters at Howrah Bridge The rally began from College square in Kolkata amid heavy security deployment
# Sentiment: {'label': 'positive', 'score': 0.00031460871105082333}
# --------------------------------------------------------------------------------
# Text: Auto drivers’ society mulls AI-based queue system
# Sentiment: {'label': 'positive', 'score': 0.0007072496809996665}
# --------------------------------------------------------------------------------
# Text: Why IAS needs to be more specialised An IAS officer often knows his or her limitations and, especially in highly specialised agencies, is wise enough to serve an ornamental function while letting the domain experts come close to making decisions and setting policies
# Sentiment: {'label': 'positive', 'score': 0.00010987839777953923}
# --------------------------------------------------------------------------------
# Text: Indians who migrate abroad see incomes double; residents need 20 years to catch up As their incomes increase by more than 100% when they move abroad, most Indians do not return home even if they are paid more than they were earlier
# Sentiment: {'label': 'positive', 'score': 9.704948752187192e-05}
# --------------------------------------------------------------------------------
# Text: A day before Darshan’s photo and video went viral, CCB raid on Parappana Agrahara Central Prison found nothing
# Sentiment: {'label': 'positive', 'score': 0.005216742400079966}
# --------------------------------------------------------------------------------
# Text: Rowdy sheeters flaunting their proximity to Darshan exposed illegalities in prison
# Sentiment: {'label': 'positive', 'score': 0.00014661200111731887}
# --------------------------------------------------------------------------------
# Text: Morning Digest: Champai Soren to join BJP on August 30; PM Modi briefs U.S. President Joe Biden on Ukraine visit in call, and more Here is a select list of stories to start the day
# Sentiment: {'label': 'positive', 'score': 0.005191050935536623}
# --------------------------------------------------------------------------------
# Text: Jobless dole helps Karnataka youth, but many find it insufficient Government data show the highest number of beneficiaries, 77,550 people, as OBCs. 20,485 beneficiaries were Dalits, while 8,435 were Adivasis. 14,134 beneficiaries were from the general category
# Sentiment: {'label': 'positive', 'score': 9.346842125523835e-05}
# --------------------------------------------------------------------------------
# Text: Karnataka CM and HDK spar over use of whitener
# Sentiment: {'label': 'positive', 'score': 0.0006282000103965402}
# --------------------------------------------------------------------------------
# Text: Karnataka launches pilot project experimenting with ovitraps to control spread of dengue and malaria
# Sentiment: {'label': 'positive', 'score': 0.0015534763224422932}
# --------------------------------------------------------------------------------
# Text: Proposal made to install AI-powered cameras in Parappana Agrahara Central Prison
# Sentiment: {'label': 'positive', 'score': 0.0007384085329249501}
# --------------------------------------------------------------------------------
# Text: Class 10 annual exam-3 results announced in Karnataka
# Sentiment: {'label': 'positive', 'score': 0.0009991548722609878}
# --------------------------------------------------------------------------------
# Text: 2003 Alipiri blast accused Kollam Gangireddy in police custody
# Sentiment: {'label': 'positive', 'score': 0.0005737142637372017}
# --------------------------------------------------------------------------------
# Text: Development and welfare will go hand in hand, says Minister
# Sentiment: {'label': 'positive', 'score': 0.0003395786916371435}
# --------------------------------------------------------------------------------
# Text: Andhra Pradesh govt. to release series of policies in next couple of months
# Sentiment: {'label': 'positive', 'score': 0.003512559924274683}
# --------------------------------------------------------------------------------
# Text: NTR Police Commissionerate plans to create 2 lakh cyber soldiers The Police, in association with cyber soldiers, will sensitise people to various online frauds, says Police Commissioner S.V. Rajasekhar Babu, adding that focus will be laid on educational institutions
# Sentiment: {'label': 'positive', 'score': 0.00017762840434443206}
# --------------------------------------------------------------------------------
# Text: Communal tension in West Tripura as houses burnt and looted, troops deployed 12 houses were burned down, 3 shops were looted and a place of worship was damaged; around 15 displaced families were given shelter in a government school
# Sentiment: {'label': 'positive', 'score': 0.003397078951820731}
# --------------------------------------------------------------------------------
# Text: 14 held for storing and selling e-cigarettes, button-actuated knives in Delhi-NCR area Crime Branch officials received an input regarding some persons selling e-cigarettes in Delhi, and some other suppliers storing e-cigarettes in bulk quantity in Old Delhi area
# Sentiment: {'label': 'positive', 'score': 0.0036159763112664223}
# --------------------------------------------------------------------------------
# Text: Denial of approval for AIIMS: LDF organises jatha in Balussery
# Sentiment: {'label': 'positive', 'score': 0.001018756185658276}
# --------------------------------------------------------------------------------
# Text: Kerala to get three registered vehicle scrapping units The facilities are being established to implement the Centre’s scrapping policy regarding vehicles that are over 15 years old; one unit to be a joint venture between KSRTC and Braithwaite and Co Ltd., a Central PSU under the Railway Ministry
# Sentiment: {'label': 'positive', 'score': 0.0012958971783518791}
# --------------------------------------------------------------------------------
# Text: Hema Committee report: AITUC to hold agitations seeking action against accused in cinema
# Sentiment: {'label': 'positive', 'score': 0.0005144884926266968}
# --------------------------------------------------------------------------------
# Text: Wayanad landslides: Search for missing persons at Chooralmala halted due to inclement weather The discovery of body parts serves as a heart-wrenching reminder of the calamity’s magnitude, even as the search for missing persons continues.
# Sentiment: {'label': 'positive', 'score': 0.0011536406818777323}
# --------------------------------------------------------------------------------
# Text: J&K polls: Congress announces first list of nine candidates The announcement came after the Congress clinched a seat-sharing deal with ally National Conference (NC)
# Sentiment: {'label': 'positive', 'score': 0.00176669517531991}
# --------------------------------------------------------------------------------
# Text: HC directs Warangal authorities not to dispossess house owners near Chinna Waddepally tank without following procedure
# Sentiment: {'label': 'positive', 'score': 0.014576943591237068}
# --------------------------------------------------------------------------------
# Text: Akbaruddin Owaisi appeals against clearance of encroachments in Surram Cheruvu
# Sentiment: {'label': 'positive', 'score': 0.0011959474068135023}
# --------------------------------------------------------------------------------
# Text: AICC leaning towards BC leader as TPCC chief to balance caste equation in Telangana Since 1992, party has been maintaining strategic caste balance between OC, BC, SC/STs.
# Sentiment: {'label': 'positive', 'score': 0.004673553630709648}
# --------------------------------------------------------------------------------
# Text: Teachers’ association opposes Unified Pension Scheme
# Sentiment: {'label': 'positive', 'score': 0.0005986368632875383}
# --------------------------------------------------------------------------------
# Text: Headmaster’s voluntary initiative helps remote tribal hamlet get a ‘kutcha’ road in Bhadrachalam Agency
# Sentiment: {'label': 'positive', 'score': 0.0009069381048902869}
# --------------------------------------------------------------------------------
# Text: ‘Waqf (Amendment) Bill infringes on freedom of religion’
# Sentiment: {'label': 'positive', 'score': 0.0004399787576403469}
# --------------------------------------------------------------------------------
# Text: Modi briefs Biden on Ukraine visit in call, discusses ‘shared concerns’ about Bangladesh In a significant departure from the MEA statement, the U.S. White House made no mention of Bangladesh during the leaders call in its readout, issued hours later.
# Sentiment: {'label': 'positive', 'score': 0.0010809175437316298}
# --------------------------------------------------------------------------------
# Text: Public representatives hail P.V.G. Raju’s contribution for development of Vizianagaram
# Sentiment: {'label': 'positive', 'score': 0.0008604481699876487}
# --------------------------------------------------------------------------------
# Text: Industries directed to ensure two week training programme for staff
# Sentiment: {'label': 'positive', 'score': 0.001371556194499135}
# --------------------------------------------------------------------------------
# Text: Over 1.2 lakh women to be benefitted from Lakhpati Didi scheme in Nellore More women SHGs will be provided financial assistance in a phased manner, says DRDA Project Director Sambasiva Reddy
# Sentiment: {'label': 'positive', 'score': 0.03410274535417557}
# --------------------------------------------------------------------------------
# Text: Oberoi Group speeds up proposed ₹250-crore Pichuka Lanka resort project in Konaseema A team led by Oberoi Group Vice Chairman on Monday inspected the 56-acre site; Tourism Minister Kandula Durgesh explains  tourism potential in the first field inspection
# Sentiment: {'label': 'positive', 'score': 0.02112608589231968}
# --------------------------------------------------------------------------------
# Text: Kochi Corporation steps up mosquito control drive; fines to be imposed on city residents
# Sentiment: {'label': 'positive', 'score': 0.0005393828032538295}
# --------------------------------------------------------------------------------
# Text: Promising startups on quantum computing to get govt. grants National Quantum Mission has identified 10-15 startups for the purpose
# Sentiment: {'label': 'positive', 'score': 0.0010042308131232858}
# --------------------------------------------------------------------------------
# Text: Incubation centre at govt. model school in Villupuram to introduce students to wildlife conservation
# Sentiment: {'label': 'positive', 'score': 0.0012788705062121153}
# --------------------------------------------------------------------------------
# Text: Residents block road in Sholinghur against discharge of sewage
# Sentiment: {'label': 'positive', 'score': 0.0024065938778221607}
# --------------------------------------------------------------------------------
# Text: Baby killed, 20 others injured in road accident near Arani
# Sentiment: {'label': 'positive', 'score': 0.21736274659633636}
# --------------------------------------------------------------------------------
# Text: Rajasthan government to position State as medical tourist destination ‘Heal in Rajasthan’ policy to be launched soon; committee appointed to formulate policy
# Sentiment: {'label': 'positive', 'score': 0.005670937243849039}
# --------------------------------------------------------------------------------
# Text: Four people arrested for hunting spotted deer in Sakrebailu range in Shivamogga
# Sentiment: {'label': 'positive', 'score': 0.03784151002764702}
# --------------------------------------------------------------------------------
# Text: Kanimozhi meets Durai Dayanidhi at CMC, Vellore
# Sentiment: {'label': 'positive', 'score': 0.01667504943907261}
# --------------------------------------------------------------------------------
# Text: Boy dies as silver peacock falls on him from chariot during festivities in Belagavi district
# Sentiment: {'label': 'positive', 'score': 0.0001122549656429328}
# --------------------------------------------------------------------------------
# Text: KASSIA submits memorandum to Bescom MD
# Sentiment: {'label': 'positive', 'score': 0.001344994525425136}
# --------------------------------------------------------------------------------
# Text: Three dead as tractor-trailer swept away amid rain in Gujarat Incessant showers inundate low-lying areas in over a dozen districts as officials shift over 18,000 people to safety; IMD has predicted heavy rain for next three days
# Sentiment: {'label': 'positive', 'score': 0.00025360126164741814}
# --------------------------------------------------------------------------------
# Text: Janaagraha hosts roundtable discussion led by NITI Aayog vice chairperson on Bengaluru
# Sentiment: {'label': 'positive', 'score': 0.0006590785342268646}
# --------------------------------------------------------------------------------
# Text: Fresh allegations roil Malayalam film industry More women come forward with complaints against prominent actors and a filmmaker.
# Sentiment: {'label': 'positive', 'score': 0.0013551127631217241}
# --------------------------------------------------------------------------------
# Text: BJP urges Ravi Ganiga to name those who tried to lure him
# Sentiment: {'label': 'positive', 'score': 0.0025037741288542747}
# --------------------------------------------------------------------------------
# Text: Land allotted to educational trust as per norms without subsidy, clarify M.B. Patil and Priyank Kharge Large and Medium Industries M.B. Patil questions erstwhile BJP government for allotting 116 acres to Chanakya University in an industrial area for ₹50 crore, which resulted in ₹137 crore loss to the State exchequer
# Sentiment: {'label': 'positive', 'score': 0.003707898547872901}
# --------------------------------------------------------------------------------
# Text: Divided, we will be slaughtered, says Yogi while pitching Bangladesh unrest in U.P. The Chief Minister’s remarks have assumed political significance as they have come ahead of the upcoming Assembly by-polls on 10 seats in the State which are expected to test the BJP
# Sentiment: {'label': 'positive', 'score': 6.843429582659155e-05}
# --------------------------------------------------------------------------------
# Text: Karnataka govt. asks committee to submit report on Unified Pension Scheme The committee is currently looking into demands of NPS employees to roll back to OPS; NPS employees oppose UPS
# Sentiment: {'label': 'positive', 'score': 0.00012747147411573678}
# --------------------------------------------------------------------------------
# Text: Chhattisgarh recommends CBI probe into the Mahadev betting app scam Corruption allegations against the then Bhupesh Baghel-led Congress government had emerged as one of the main themes in the BJP’s campaign in the Assembly elections in late 2023, and the alleged Mahadev betting app scam was key among those allegations
# Sentiment: {'label': 'positive', 'score': 0.01244465820491314}
# --------------------------------------------------------------------------------
# Text: Centre yet to list violation of ground rules by Kuki-Zo insurgent groups: senior leader of Kuki National Organisation Demand for separate administration in Manipur is within the framework of the Constitution, Seilen Haokip says.
# Sentiment: {'label': 'positive', 'score': 0.0030456914100795984}
# --------------------------------------------------------------------------------
# Text: Personal identification document made mandatory for property registration
# Sentiment: {'label': 'positive', 'score': 0.001191247021779418}
# --------------------------------------------------------------------------------
# Text: RJD MP slams Manoj Tiwari for remark on Rahul Gandhi, demands apology Buxar MP Sudhakar Singh said Manoj Tiwari has maligned the name of Bihar by singing ‘vulgar’ Bhojpuri songs. He said BJP leaders are becoming a laughing stock by insulting Rahul Gandhi
# Sentiment: {'label': 'positive', 'score': 0.0004885576781816781}
# --------------------------------------------------------------------------------
# Text: Six killed after car falls into valley in Kadapa
# Sentiment: {'label': 'positive', 'score': 0.0005180723965167999}
# --------------------------------------------------------------------------------
# Text: AIUDF meets Assam Governor, seeks action against communal groups Several organisations representing indigenous communities have asked migrant Muslims, referred to as Miya, to leave eastern Assam following a gang-rape case
# Sentiment: {'label': 'positive', 'score': 0.001303263008594513}
# --------------------------------------------------------------------------------
# Text: Vajra Siri theatre festival in Dharwad from Aug. 31 Abhinaya Bharati Ranga Samsthe is organising the three-day theatre festival
# Sentiment: {'label': 'positive', 'score': 0.214647114276886}
# --------------------------------------------------------------------------------
# Text: Bail should not suffer for lack of people to stand surety: SC Bench to the rescue of Girish Gandhi who got bail in 13 separate cases of criminal breach of trust, cheating and criminal intimidation, but could only get two pairs of people to stand surety for his bail
# Sentiment: {'label': 'positive', 'score': 0.00013857211160939187}
# --------------------------------------------------------------------------------
# Text: Video surfaces of crowd at R.G. Kar Hospital seminar room, police say crime scene not tampered with An officer of Kolkata Police said none of the ‘outsiders’ seen in the video apart from the parents were allowed inside the cordoned-off area in the seminar room where the body was found
# Sentiment: {'label': 'positive', 'score': 0.0002856102946680039}
# --------------------------------------------------------------------------------
# Text: Two more pharma blast victims succumb to injuries, taking toll to three Ex gratia of ₹1 crore each was given to the families of two deceased, says Collector
# Sentiment: {'label': 'positive', 'score': 0.7968154549598694}
# --------------------------------------------------------------------------------
# Text: Sri Krishna Janmashtami celebrated with fervour in twin cities Various events mark the celebrations with scores of devotees participating in various public events
# Sentiment: {'label': 'positive', 'score': 0.00047191852354444563}
# --------------------------------------------------------------------------------
# Text: ‘Anywhere registration’ of property within district to begin from September 2 According to the concept, people across Karnataka will have the freedom to choose the sub-registrar office of their choice for any registration work within their district
# Sentiment: {'label': 'positive', 'score': 0.0009963527554646134}
# --------------------------------------------------------------------------------
# Text: Eastern wall of 14th-century Penukonda Fort partially collapses The incident is being attributed to the region’s intermittent rains over the past two months, which caused the wall to become moist
# Sentiment: {'label': 'positive', 'score': 0.003642836818471551}
# --------------------------------------------------------------------------------
# Text: Post-Disaster Needs Assessment team begins study on Chooralmala landslides
# Sentiment: {'label': 'positive', 'score': 0.00027896728715859354}
# --------------------------------------------------------------------------------
# Text: Array of devotional programmes mark celebration of Sri Krishna Janmashtami
# Sentiment: {'label': 'positive', 'score': 0.0006168082472868264}
# --------------------------------------------------------------------------------
# Text: Binoy Viswam seeks Civil Aviation Minister’s intervention to lower airfares during Onam season
# Sentiment: {'label': 'positive', 'score': 0.0014463929692283273}
# --------------------------------------------------------------------------------
# Text: Foreign rebels plan to use Mizoram as training ground, suspect agencies A purported letter from an outfit of a small ethnic community, the Khumi National Democratic Party, in Bangladesh seeking space for a training camp in the State give security agencies the lead
# Sentiment: {'label': 'positive', 'score': 0.0008327408577315509}
# --------------------------------------------------------------------------------
# Text: Video of man asking for rape of Trinamool leader Abhishek Banerjee’s daughter goes viral; rights body takes suo motu case West Bengal child rights commission files suo motu case, calls for immediate police action
# Sentiment: {'label': 'positive', 'score': 0.0003054410917684436}
# --------------------------------------------------------------------------------
# Text: CM unveils statues of Sangolli Rayanna at four places in Belagavi district While a mini stone fort of Sangolli Rayanna was inaugurated in Koujalagi, the statues were unveiled in Kalliguddi, Yadwad and Kalloli villages
# Sentiment: {'label': 'positive', 'score': 0.05321398004889488}
# --------------------------------------------------------------------------------
# Text: Arihant Group signs JDA for ₹500 crore commercial development adjacent to Hilton Chennai
# Sentiment: {'label': 'positive', 'score': 0.0009152715792879462}
# --------------------------------------------------------------------------------
# Text: JNCASR along with HZL to develop new variants of zinc materials; enhance indigenous Zn-ion battery technologies
# Sentiment: {'label': 'positive', 'score': 0.0011467456351965666}
# --------------------------------------------------------------------------------
# Text: Sridhar Babu test-drives IIT Hyderabad’s driverless vehicle
# Sentiment: {'label': 'positive', 'score': 0.0005062947748228908}
# --------------------------------------------------------------------------------
